# %% [markdown]
# # Bronze → Silver transform (placeholder)
#
# Implement in Fabric:
# - Read Bronze (OneLake shortcut / ADLS)
# - Clean + conform (types, dedupe)
# - Write Silver Delta tables

# %%
# Placeholder
# df = spark.read.format('parquet').load(raw_path)
# ... clean ...
# df.write.mode('overwrite').format('delta').saveAsTable('bank_silver.stg_payments')
